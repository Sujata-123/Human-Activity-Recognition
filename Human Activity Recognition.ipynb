# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/human+activity+recognition+using+smartphones#

# %% [markdown]
# ## Human Activity Recognition

# %% [markdown]
# * This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# * This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.

# %% [markdown]
# ## How data was recorded

# %% [markdown]
# * By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(tAcc-XYZ) from accelerometer and '3-axial angular velocity' (tGyro-XYZ) from Gyroscope with several variations.
#
# * prefix 't' in those metrics denotes time.
#
# * suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.

# %% [markdown]
# ## Y_Labels(Encoded)

# %% [markdown]
# * In the dataset, Y_labels are represented as numbers from 1 to 6 as their identifiers.
#
# * WALKING as 1
# * WALKING_UPSTAIRS as 2
# * WALKING_DOWNSTAIRS as 3
# * SITTING as 4
# * STANDING as 5
# * LAYING as 6

# %% [markdown]
# ## Train and test data were separated

# %% [markdown]
# * The readings from 70% of the volunteers were taken as trianing data and remaining 30% subjects recordings were taken for test data

# %% [markdown]
# ## Overview of dataset

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
# * Walking
# * WalkingUpstairs
# * WalkingDownstairs
# * Standing
# * Sitting
# * Lying.
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings, which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.

# %% [markdown]
# ## Problem Framework

# %% [markdown]
# * 30 subjects(volunteers) data is randomly split to 70%(21) test and 30%(7) train data.
# * Each datapoint corresponds one of the 6 Activities.

# %% [markdown]
# ## Problem Statement
# * Give a new datapoint we have to predict the activity

# %%
import numpy as np
import pandas as pd

# %%
features=list()
with open("features.txt") as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# ## Obtain the train data

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('X_train.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_train['subject'] = pd.read_csv('subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 6614           0.207675          -0.037987          -0.137125
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 6614         -0.270827         -0.129798         -0.388373         -0.301091
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 6614         -0.142537          -0.44755         -0.128307  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 6614                     0.219027                              0.267134
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 6614                         -0.781625                              -0.66653
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 6614             -0.545329              0.331459              0.228532
#
#       subject  Activity      ActivityName
# 6614       28         2  WALKING_UPSTAIRS
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Obtain the test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('X_test.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 1384           0.271178          -0.030668          -0.105884
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 1384          -0.99648         -0.974333         -0.986583         -0.996768
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 1384         -0.976815         -0.988083         -0.945582  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 1384                    -0.003961                              0.036996
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 1384                          0.504146                             -0.495993
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 1384             -0.800333               0.23614               0.01593
#
#       subject  Activity  ActivityName
# 1384       12         5      STANDING
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ## 1. Checking for duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. Checking for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# * We have got almost same number of reading from all the subjects

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation
# * Our data is well balanced(almost)

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
train.to_csv('train.csv', index=False)
test.to_csv('test.csv', index=False)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge
# #### Static and Dynamic Activities
# #### In static activities (sit, stand, lie down) motion information will not be very useful.
# #### In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Magnitude of an acceleration can separate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
#
# * If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# * If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# * If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# * We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
#
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# ## Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.404s...
# [t-SNE] Computed neighbors for 7352 samples in 42.308s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635855
# [t-SNE] Computed conditional probabilities in 0.178s
# [t-SNE] Iteration 50: error = 124.6541138, gradient norm = 0.0276180 (50 iterations in 11.297s)
# [t-SNE] Iteration 100: error = 107.1339264, gradient norm = 0.0272262 (50 iterations in 3.899s)
# [t-SNE] Iteration 150: error = 101.0077744, gradient norm = 0.0189009 (50 iterations in 2.834s)
# [t-SNE] Iteration 200: error = 97.6113052, gradient norm = 0.0186618 (50 iterations in 2.838s)
# [t-SNE] Iteration 250: error = 95.3083191, gradient norm = 0.0134196 (50 iterations in 2.839s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.308319
# [t-SNE] Iteration 300: error = 4.1200762, gradient norm = 0.0015596 (50 iterations in 2.646s)
# [t-SNE] Iteration 350: error = 3.2121000, gradient norm = 0.0009987 (50 iterations in 2.688s)
# [t-SNE] Iteration 400: error = 2.7841420, gradient norm = 0.0007206 (50 iterations in 2.823s)
# [t-SNE] Iteration 450: error = 2.5208201, gradient norm = 0.0005645 (50 iterations in 2.582s)
# [t-SNE] Iteration 500: error = 2.3377345, gradient norm = 0.0004786 (50 iterations in 2.767s)
# [t-SNE] Iteration 550: error = 2.2001634, gradient norm = 0.0004169 (50 iterations in 2.827s)
# [t-SNE] Iteration 600: error = 2.0906627, gradient norm = 0.0003654 (50 iterations in 2.620s)
# [t-SNE] Iteration 650: error = 2.0007145, gradient norm = 0.0003296 (50 iterations in 2.705s)
# [t-SNE] Iteration 700: error = 1.9249496, gradient norm = 0.0003002 (50 iterations in 3.004s)
# [t-SNE] Iteration 750: error = 1.8600103, gradient norm = 0.0002771 (50 iterations in 3.083s)
# [t-SNE] Iteration 800: error = 1.8031992, gradient norm = 0.0002548 (50 iterations in 3.460s)
# [t-SNE] Iteration 850: error = 1.7529256, gradient norm = 0.0002396 (50 iterations in 3.406s)
# [t-SNE] Iteration 900: error = 1.7080622, gradient norm = 0.0002264 (50 iterations in 3.901s)
# [t-SNE] Iteration 950: error = 1.6678145, gradient norm = 0.0002141 (50 iterations in 3.321s)
# [t-SNE] Iteration 1000: error = 1.6315410, gradient norm = 0.0002005 (50 iterations in 4.425s)
# [t-SNE] KL divergence after 1000 iterations: 1.631541
# Done..
# Creating plot for this t-sne visualization..
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.439s...
# [t-SNE] Computed neighbors for 7352 samples in 54.106s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.249s
# [t-SNE] Iteration 50: error = 114.0501328, gradient norm = 0.0225081 (50 iterations in 6.185s)
# [t-SNE] Iteration 100: error = 97.7225571, gradient norm = 0.0166562 (50 iterations in 4.368s)
# [t-SNE] Iteration 150: error = 93.4175262, gradient norm = 0.0098991 (50 iterations in 4.427s)
# [t-SNE] Iteration 200: error = 91.4456329, gradient norm = 0.0079735 (50 iterations in 4.500s)
# [t-SNE] Iteration 250: error = 90.2567139, gradient norm = 0.0067093 (50 iterations in 3.906s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.256714
# [t-SNE] Iteration 300: error = 3.5768490, gradient norm = 0.0014556 (50 iterations in 3.346s)
# [t-SNE] Iteration 350: error = 2.8195152, gradient norm = 0.0007586 (50 iterations in 3.058s)
# [t-SNE] Iteration 400: error = 2.4392762, gradient norm = 0.0005199 (50 iterations in 3.136s)
# [t-SNE] Iteration 450: error = 2.2210698, gradient norm = 0.0004050 (50 iterations in 3.212s)
# [t-SNE] Iteration 500: error = 2.0763431, gradient norm = 0.0003308 (50 iterations in 3.224s)
# [t-SNE] Iteration 550: error = 1.9713093, gradient norm = 0.0002843 (50 iterations in 3.262s)
# [t-SNE] Iteration 600: error = 1.8903553, gradient norm = 0.0002446 (50 iterations in 3.325s)
# [t-SNE] Iteration 650: error = 1.8253530, gradient norm = 0.0002211 (50 iterations in 3.424s)
# [t-SNE] Iteration 700: error = 1.7714365, gradient norm = 0.0001963 (50 iterations in 3.264s)
# [t-SNE] Iteration 750: error = 1.7259972, gradient norm = 0.0001793 (50 iterations in 3.288s)
# [t-SNE] Iteration 800: error = 1.6871063, gradient norm = 0.0001653 (50 iterations in 3.283s)
# [t-SNE] Iteration 850: error = 1.6530942, gradient norm = 0.0001535 (50 iterations in 3.362s)
# [t-SNE] Iteration 900: error = 1.6233733, gradient norm = 0.0001430 (50 iterations in 3.391s)
# [t-SNE] Iteration 950: error = 1.5971664, gradient norm = 0.0001334 (50 iterations in 3.316s)
# [t-SNE] Iteration 1000: error = 1.5739009, gradient norm = 0.0001258 (50 iterations in 3.351s)
# [t-SNE] KL divergence after 1000 iterations: 1.573901
# Done..
# Creating plot for this t-sne visualization..
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.334s...
# [t-SNE] Computed neighbors for 7352 samples in 53.936s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.125s
# [t-SNE] Iteration 50: error = 105.9538345, gradient norm = 0.0190651 (50 iterations in 5.646s)
# [t-SNE] Iteration 100: error = 90.1702042, gradient norm = 0.0108784 (50 iterations in 3.932s)
# [t-SNE] Iteration 150: error = 87.1873245, gradient norm = 0.0054684 (50 iterations in 3.380s)
# [t-SNE] Iteration 200: error = 85.9835510, gradient norm = 0.0058495 (50 iterations in 3.338s)
# [t-SNE] Iteration 250: error = 85.3074265, gradient norm = 0.0028307 (50 iterations in 3.457s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.307426
# [t-SNE] Iteration 300: error = 3.1313941, gradient norm = 0.0013888 (50 iterations in 3.402s)
# [t-SNE] Iteration 350: error = 2.4883268, gradient norm = 0.0006484 (50 iterations in 3.950s)
# [t-SNE] Iteration 400: error = 2.1688387, gradient norm = 0.0004231 (50 iterations in 3.546s)
# [t-SNE] Iteration 450: error = 1.9846709, gradient norm = 0.0003120 (50 iterations in 3.492s)
# [t-SNE] Iteration 500: error = 1.8667381, gradient norm = 0.0002517 (50 iterations in 3.327s)
# [t-SNE] Iteration 550: error = 1.7836572, gradient norm = 0.0002100 (50 iterations in 3.357s)
# [t-SNE] Iteration 600: error = 1.7210824, gradient norm = 0.0001811 (50 iterations in 3.574s)
# [t-SNE] Iteration 650: error = 1.6720061, gradient norm = 0.0001580 (50 iterations in 3.652s)
# [t-SNE] Iteration 700: error = 1.6325002, gradient norm = 0.0001425 (50 iterations in 3.513s)
# [t-SNE] Iteration 750: error = 1.6000111, gradient norm = 0.0001305 (50 iterations in 3.528s)
# [t-SNE] Iteration 800: error = 1.5728451, gradient norm = 0.0001176 (50 iterations in 3.551s)
# [t-SNE] Iteration 850: error = 1.5495951, gradient norm = 0.0001095 (50 iterations in 3.578s)
# [t-SNE] Iteration 900: error = 1.5295532, gradient norm = 0.0001028 (50 iterations in 3.635s)
# [t-SNE] Iteration 950: error = 1.5119728, gradient norm = 0.0000947 (50 iterations in 3.504s)
# [t-SNE] Iteration 1000: error = 1.4964781, gradient norm = 0.0000906 (50 iterations in 3.541s)
# [t-SNE] KL divergence after 1000 iterations: 1.496478
# Done..
# Creating plot for this t-sne visualization..
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.259s...
# [t-SNE] Computed neighbors for 7352 samples in 43.569s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.281s
# [t-SNE] Iteration 50: error = 96.7349472, gradient norm = 0.0289417 (50 iterations in 5.020s)
# [t-SNE] Iteration 100: error = 84.1443939, gradient norm = 0.0079976 (50 iterations in 3.561s)
# [t-SNE] Iteration 150: error = 81.9248505, gradient norm = 0.0044201 (50 iterations in 3.145s)
# [t-SNE] Iteration 200: error = 81.1621094, gradient norm = 0.0023918 (50 iterations in 2.908s)
# [t-SNE] Iteration 250: error = 80.7595825, gradient norm = 0.0023474 (50 iterations in 3.560s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.759583
# [t-SNE] Iteration 300: error = 2.7035446, gradient norm = 0.0013131 (50 iterations in 3.273s)
# [t-SNE] Iteration 350: error = 2.1660407, gradient norm = 0.0005793 (50 iterations in 2.798s)
# [t-SNE] Iteration 400: error = 1.9154800, gradient norm = 0.0003488 (50 iterations in 2.623s)
# [t-SNE] Iteration 450: error = 1.7685513, gradient norm = 0.0002479 (50 iterations in 2.745s)
# [t-SNE] Iteration 500: error = 1.6747866, gradient norm = 0.0001913 (50 iterations in 2.565s)
# [t-SNE] Iteration 550: error = 1.6104901, gradient norm = 0.0001599 (50 iterations in 2.549s)
# [t-SNE] Iteration 600: error = 1.5639316, gradient norm = 0.0001334 (50 iterations in 2.585s)
# [t-SNE] Iteration 650: error = 1.5285647, gradient norm = 0.0001177 (50 iterations in 2.570s)
# [t-SNE] Iteration 700: error = 1.5010012, gradient norm = 0.0001056 (50 iterations in 2.533s)
# [t-SNE] Iteration 750: error = 1.4788086, gradient norm = 0.0000965 (50 iterations in 2.868s)
# [t-SNE] Iteration 800: error = 1.4610131, gradient norm = 0.0000905 (50 iterations in 2.796s)
# [t-SNE] Iteration 850: error = 1.4467165, gradient norm = 0.0000850 (50 iterations in 2.864s)
# [t-SNE] Iteration 900: error = 1.4349233, gradient norm = 0.0000792 (50 iterations in 2.598s)
# [t-SNE] Iteration 950: error = 1.4249364, gradient norm = 0.0000754 (50 iterations in 2.716s)
# [t-SNE] Iteration 1000: error = 1.4165783, gradient norm = 0.0000727 (50 iterations in 2.600s)
# [t-SNE] KL divergence after 1000 iterations: 1.416578
# Done..
# Creating plot for this t-sne visualization..
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.256s...
# [t-SNE] Computed neighbors for 7352 samples in 47.919s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.472s
# [t-SNE] Iteration 50: error = 85.5127716, gradient norm = 0.0287119 (50 iterations in 6.509s)
# [t-SNE] Iteration 100: error = 75.5744400, gradient norm = 0.0040924 (50 iterations in 6.317s)
# [t-SNE] Iteration 150: error = 74.5957184, gradient norm = 0.0021916 (50 iterations in 4.014s)
# [t-SNE] Iteration 200: error = 74.2325592, gradient norm = 0.0015511 (50 iterations in 3.918s)
# [t-SNE] Iteration 250: error = 74.0545578, gradient norm = 0.0012594 (50 iterations in 3.926s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.054558
# [t-SNE] Iteration 300: error = 2.1528878, gradient norm = 0.0011775 (50 iterations in 3.660s)
# [t-SNE] Iteration 350: error = 1.7561101, gradient norm = 0.0004871 (50 iterations in 3.365s)
# [t-SNE] Iteration 400: error = 1.5869986, gradient norm = 0.0002792 (50 iterations in 3.339s)
# [t-SNE] Iteration 450: error = 1.4930116, gradient norm = 0.0001899 (50 iterations in 3.359s)
# [t-SNE] Iteration 500: error = 1.4322641, gradient norm = 0.0001425 (50 iterations in 3.361s)
# [t-SNE] Iteration 550: error = 1.3912977, gradient norm = 0.0001133 (50 iterations in 3.350s)
# [t-SNE] Iteration 600: error = 1.3623606, gradient norm = 0.0000950 (50 iterations in 3.373s)
# [t-SNE] Iteration 650: error = 1.3411869, gradient norm = 0.0000839 (50 iterations in 3.403s)
# [t-SNE] Iteration 700: error = 1.3256164, gradient norm = 0.0000770 (50 iterations in 3.431s)
# [t-SNE] Iteration 750: error = 1.3142935, gradient norm = 0.0000694 (50 iterations in 3.410s)
# [t-SNE] Iteration 800: error = 1.3054647, gradient norm = 0.0000643 (50 iterations in 3.413s)
# [t-SNE] Iteration 850: error = 1.2982116, gradient norm = 0.0000614 (50 iterations in 3.474s)
# [t-SNE] Iteration 900: error = 1.2925695, gradient norm = 0.0000598 (50 iterations in 3.431s)
# [t-SNE] Iteration 950: error = 1.2882607, gradient norm = 0.0000543 (50 iterations in 3.448s)
# [t-SNE] Iteration 1000: error = 1.2843238, gradient norm = 0.0000520 (50 iterations in 3.521s)
# [t-SNE] KL divergence after 1000 iterations: 1.284324
# Done..
# Creating plot for this t-sne visualization..
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
